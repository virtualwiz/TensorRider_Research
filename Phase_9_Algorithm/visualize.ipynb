# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import animation
from time import ctime,sleep

# %%
npRecall = np.load("arrays.npz")
X_train = npRecall["xtr"]
y_train = npRecall["ytr"]
X_val = npRecall["xval"]
y_val = npRecall["yval"]
X_test = npRecall["xt"]
y_test = npRecall["yt"]

# %%
plt.hist(y_train)
# Out:
# (array([4.930e+02, 0.000e+00, 4.565e+03, 0.000e+00, 4.786e+03, 0.000e+00,
#         3.352e+03, 0.000e+00, 3.960e+02, 3.000e+00]),
#  array([1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. , 5.5, 6. ]),
#  <a list of 10 Patch objects>)

# %%
X_visualize = X_train.reshape(13595,60,80,1)

# %%
plt.imshow(X_visualize[1,:,:,0])

# %%
for img in range(100):
    plt.imshow(X_visualize[img,:,:,0])
    plt.show()
    sleep(0.1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-7cb25047bbb2> in <module>()
#       1 for img in range(100):
# ----> 2     plt.imshow(X_visualize[img,:,:,0])
#       3     plt.show()
#       4     sleep(0.1)
#
# D:\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, hold, data, **kwargs)
#    3187            filternorm=1, filterrad=4.0, imlim=None, resample=None, url=None,
#    3188            hold=None, data=None, **kwargs):
# -> 3189     ax = gca()
#    3190     # Deprecated: allow callers to override the hold state
#    3191     # by passing hold=True|False
#
# D:\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\pyplot.py in gca(**kwargs)
# ...
